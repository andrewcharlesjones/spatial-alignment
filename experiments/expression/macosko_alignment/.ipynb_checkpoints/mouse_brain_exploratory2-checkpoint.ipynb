# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.io import mmread
import pandas as pd
from os.path import join as pjoin

# %%
DATA_DIR = "./data/mouse_brain_slideseq/12_allMTXs_CCF"
metadata = pd.read_table(pjoin(DATA_DIR, "MBASS_d123_metadata.tsv"))
data_sparse = mmread(pjoin(DATA_DIR, "MBASS_d123_matrix.mtx"))

# %%
data = data_sparse.toarray()

# %%
metadata.head()
# Out:
#                    Unnamed: 0 orig.ident  nCount_Spatial  nFeature_Spatial  \
# 0  MBASSd123_GTTTTTTTTTTTTT-1  MBASSd123           10287              5918
# 1  MBASSd123_CGCTTTTTTTTTTT-1  MBASSd123            5650              3448
# 2  MBASSd123_CCACAGGTTTAATT-1  MBASSd123            5371              2785
# 3  MBASSd123_ACTCCGTATCATAC-1  MBASSd123            5367              2857
# 4  MBASSd123_TCCAANAGTTACCA-1  MBASSd123            4696              2468
#
#   shortName                                     longName  CCF_R  CCF_G  CCF_B  \
# 0   RSPv2/3  Retrosplenial area, ventral part, layer 2/3     26    166    152
# 1       MRN                   Midbrain reticular nucleus    255    144    255
# 2       CA1                                    Field CA1    126    208     75
# 3       MRN                   Midbrain reticular nucleus    255    144    255
# 4       CA1                                    Field CA1    126    208     75
#
# ...

# %%
sns.scatterplot(data=metadata[~metadata["isOutsideCCF"]], x="Original_x", y="Original_y", hue="longName")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
data.shape, metadata.shape
# Out:
# ((35936, 173251), (173251, 21))

# %%
plt.scatter(metadata.loc[~metadata["isOutsideCCF"], "Original_x"], metadata.loc[~metadata["isOutsideCCF"], "Original_y"], c=np.log(data[65, ~metadata["isOutsideCCF"]]), s=.5)
# plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
# Out:
# <ipython-input-60-2209e746c0ae>:1: RuntimeWarning: divide by zero encountered in log
#   plt.scatter(metadata.loc[~metadata["isOutsideCCF"], "Original_x"], metadata.loc[~metadata["isOutsideCCF"], "Original_y"], c=np.log(data[65, ~metadata["isOutsideCCF"]]), s=.5)

# %%
data[0, ~metadata["isOutsideCCF"]].max()
# Out:
# 1

# %%
gene_variances = data[:100, ~metadata["isOutsideCCF"]].var(1)

# %%
gene_variances.argmax()
# Out:
# 65
